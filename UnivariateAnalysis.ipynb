# %%
#analysis of single feature or variable
#what type of data is available numerical or categorical, depending on that we do thigs

# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv('train_titanic.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
#categorical data

#SibSp is number of siblings,it is numerical but we can treat is as categorical

# %%
#for survived

# %%
#count plot
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
print(df['Survived'].value_counts())
df['Survived'].value_counts().plot(kind='bar')
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# <Axes: >

# %%
#for Pclass
sns.countplot(x=df['Pclass'])
#we can also find mean fair in 3 classes as that give idea why pclass 3 have
#have more people in that(as fair is less)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
#for Sex
sns.countplot(x=df['Sex'])
#more male than female
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#pie chart
#if need above things in %age

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Survived'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Sex'>

# %%
#numerical data

# %%
#histogram
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
#distplot
sns.distplot(df['Age'])
# Out:
# <ipython-input-40-39f9637749b8>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#boxplot
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
df['Age'].min(),df['Age'].max(),df['Age'].mean()
# Out:
# (0.42, 80.0, 29.69911764705882)

# %%
#with distplot we can see whether skewness present in our data or not
#other way of finding out is by pandas
df['Age'].skew() # if 0 then simitrical or normal, if +ve then towards right side
#-ve means towards left sode
# Out:
# 0.38910778230082704
